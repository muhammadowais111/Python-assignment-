# %% [raw]
# 1) Area of a Rectangle:
# Write a Python program to calculate the area of a rectangle. Use the formula:
# A𝒓𝒆𝒂 = 𝒍𝒆𝒏𝒈𝒕𝒉 × 𝒘𝒊𝒅𝒕𝒉
# Take length and width as inputs from the user.

# %%
length = eval(input("Enter length : "))
width = eval(input("Enter width : "))
Area = length*width
print(f"Area = {Area}")
# Out:
# Enter length :  13
# Enter width :  2
# Area = 26

# %% [raw]
# 2) Circumference of a Circle:
# Write a Python program to calculate the circumference of a circle. Use the formula:
# C𝒊𝒓𝒄𝒖𝒎𝒇𝒆𝒓𝒆𝒏𝒄𝒆 = 𝟐𝝅𝒓
# Take the radius r as input from the user.

# %%
r = eval(input("Enter radius of circle in meters : "))
pi = 3.142
circumference = 2*pi*r
print(f"Circumference = {circumference}")
# Out:
# Enter radius of circle in meters :  2
# Circumference = 12.568

# %% [raw]
# 3) Simple Interest:
# Write a Python program to calculate the simple interest. Use the formula:
# S𝒊𝒎𝒑𝒍𝒆 𝑰𝒏𝒕𝒆𝒓𝒆𝒔𝒕 = 𝑷𝒓𝒊𝒏𝒄𝒊𝒑𝒂𝒍 × 𝑹𝒂𝒕𝒆 × 𝑻𝒊𝒎𝒆
# Take Principal, Rate, and Time as inputs from the user.

# %%
Principle = eval(input("Enter Principle : " ))
Rate = eval(input("Enter Rate : " ))
Time = eval(input("Enter Time : " ))
Simple_interest = Principle*Rate*Time
print(f"Simple Interest = {Simple_interest}")
# Out:
# Enter Principle :  12
# Enter Rate :  3
# Enter Time :  56
# Simple Interest = 2016

# %% [raw]
# 4) Speed of an Object:
# Write a Python program to calculate the speed of an object. Use the formula:
# S𝒑𝒆𝒆𝒅     =      𝑫𝒊𝒔𝒕𝒂𝒏𝒄𝒆 /    𝑻𝒊𝒎𝒆
# Take Distance and Time as inputs from the user.

# %%
Distance = eval(input("Enter distance : "))
Time = eval(input("Enter Time : "))
Speed = Distance/Time
print(f"Speed = {Speed}")
# Out:
# Enter distance :  5
# Enter Time :  2.5
# Speed = 2.0

# %% [raw]
# 5) BMI Calculator:
# Write a Python program to calculate the Body Mass Index (BMI). Use the formula:
# BMI = Weight(kg)/(Height)**2
#  Take Weight (in kilograms) and Height (in meters) as inputs from the user.

# %%
Weight = eval(input("Enter weight in kg : "))
Height = eval(input("Enter height in m : "))
BMI = Weight/(Height)**2
print(f"The Body Mass Index (BMI) is = {BMI}")
# Out:
# Enter weight in kg :  12
# Enter height in m :  3
# The Body Mass Index (BMI) is = 1.3333333333333333

# %% [raw]
# 6) Force Using Newton's Second Law:
# Write a Python program to calculate the force on an object. Use the formula:
#
# Take m (mass in kilograms) and a (acceleration in meters/second²) as inputs from the
# user.

# %%
m = eval(input("Enter mass in kg : "))
a = eval(input("Enter acceleration in m/s**2 : "))
F = m*a
print(f"Force on an object = {F}")
# Out:
# Enter mass in kg :  2
# Enter acceleration in m/s**2 :  4
# Force on an object = 8

# %% [raw]
# 7) Compound Interest:
# Write a Python program to calculate compound interest. Use the formula:
# Where:
# A= total amount
# P = principal amount
# r = annual interest rate (decimal)
# n = number of times interest is compounded per year
# t = time in years
# Take P, r, n, and t as inputs from the user.

# %%
P = eval(input("Enter principal amount : "))
r = float(input("Enter annual rate : "))
n = eval(input("Enter number of times interest is compounded per year : "))
t = eval(input("Enter time in years : "))
A = P*(1+(r/n))**n-t
print(f"Compund Interest is : {A}")
# Out:
# Enter principal amount :  12
# Enter annual rate :  2.5
# Enter number of times interest is compounded per year :  1
# Enter time in years :  2
# Compund Interest is : 40.0

# %% [raw]
# 8) Perimeter of a Triangle:
# Write a Python program to calculate the perimeter of a triangle. Use the formula:
# P𝒆𝒓𝒊𝒎𝒆𝒕𝒆𝒓 = 𝒂+𝒃+𝒄
# Take a, b, and c (lengths of the three sides) as inputs from the user.

# %%
a = eval(input("Enter a : "))
b = eval(input("Enter b : "))
c = eval(input("Enter c : "))
P = a+b+c
print(f"Perimeter of triangle = {P}")
# Out:
# Enter a :  12
# Enter b :  2
# Enter c :  3
# Perimeter of triangle = 17

# %% [raw]
# 9) Volume of a Sphere:
# Write a Python program to calculate the volume of a sphere. Use the formula:
# Take r (radius) as input from the user.

# %%
r = eval(input("Enter radius of sphere : "))
pi = 3.142
V = (4/3)*pi*r**3
print(f"Volume of sphere = {V}")
# Out:
# Enter radius of sphere :  34
# Volume of sphere = 164657.55733333333

# %% [raw]
# 10) Kinetic Energy:
# Write a Python program to calculate the kinetic energy of an object. Use the formula:
# Take m (mass in kilograms) and v (velocity in meters/second) as inputs from the user.

# %%
m = eval(input("Enter mass in kg : "))
v = eval(input("Enter velocity in m/s : "))
K_E = (1/2)*m*v**2
print(f"Kinetic Energy = {K_E}")
# Out:
# Enter mass in kg :  2
# Enter velocity in m/s :  34
# Kinetic Energy = 1156.0

# %% [raw]
# 11) Quadratic Equation Roots:
# Write a Python program to find the roots of a quadratic equation. Use the formula:
#  Take a, b, and c as inputs from the user.

# %%
import cmath
a = eval(input("Enter a : "))
b = eval(input("Enter b : "))
c = eval(input("Enter c : "))
D = (b**2)-4*a*c
x_1 = (-b+math.sqrt(D))/(2*a)
x_2 = (-b-math.sqrt(D))/(2*a)
print(f"The Quadratic roots(X) are = {x_1},{x_2}")

# %% [raw]
# 12) Temperature Conversion:
# Write a Python program to convert a temperature from Celsius to Fahrenheit. Use the
# formula:
# Take C (temperature in Celsius) as input from the user.

# %%
C = eval(input("Enter temperature in celsius : "))
F = ((9/5)*C)+32
print(f"Temperature in Fahrenheit = {F}")
# Out:
# Enter temperature in celsius :  45
# Temperature in Fahrenheit = 113.0

# %% [raw]
# 13) Gravitational Force:
# Write a Python program to calculate the gravitational force between two objects. Use
# the formula
# m1, m2 are the masses of the objects
# r = distance between the centers of the objects
# Take m1, m2 and r as inputs from the user.

# %%
m1 = eval(input("Enter m1 in kg : "))
m2 = eval(input("Enter m2 in kg : "))
r = eval(input("Enter radius in m : "))
G = 6.67e-11
F = (G*m1*m2)/r**2
print(f"Gavitaional Force is = {F}")
# Out:
# Enter m1 in kg :  34
# Enter m2 in kg :  56
# Enter radius in m :  2
# Gavitaional Force is = 3.17492e-08

# %% [raw]
#  14) Volume of a Cylinder:
# Write a Python program to calculate the volume of a cylinder. Use the formula:
# Take radius(r) and height(h) as inputs from the user

# %%
r = eval(input("Enter radius of cylinder in m : "))
h = eval(input("Enter height of cylinder in m : "))
pi = 3.142
V = pi*r**2*h
print(f"Volume of cylinder = {V}")
# Out:
# Enter radius of cylinder in m :  12
# Enter height of cylinder in m :  34
# Volume of cylinder = 15383.232

# %% [raw]
# 15) Pressure:
# Write a Python program to calculate the pressure exerted by a force on a surface. Use
# the formula:
# P = pressure
# F = force
# A = area
# Take F(force) and A(area) as inputs from the user.

# %%
F = eval(input("Enter Force in N : "))
A = eval(input("Enter Area in m**2 : "))
P = F/A
print(f"Pressure exerted by force on surface is = {P}")
# Out:
# Enter Force in N :  3
# Enter Area in m**2 :  4
# Pressure exerted by force on surface is = 0.75

# %% [raw]
# 16) Electric Power:
# Write a Python program to calculate the electric power consumed. Use the formula:
# where:
# P = power
# V = voltage
# I = current
# Take V(voltage) and I(current) as inputs from the user.

# %%
V = eval(input("Enter Voltage in Volts : "))
I = eval(input("Enter Current in Ampere : "))
P = V/I
print(f"Electric power is {P}")
# Out:
# Enter Voltage in Volts :  34
# Enter Current in Ampere :  12
# Electric power is 2.8333333333333335

# %% [raw]
# 17) Perimeter of a Circle (Circumference):
# Write a Python program to calculate the perimeter (circumference) of a circle. Use the
# formula:
# Take r (radius) as input from the user.

# %%
r = eval(input("Enter radius in m : "))
pi = 3.142
P = 2*pi*r
print(f"Perimeter of circle = {P}")
# Out:
# Enter radius in m :  34
# Perimeter of circle = 213.656

# %% [raw]
# 18) Future Value in Savings:
# Write a Python program to calculate the future value of an investment. Use the formula:
# where:
# o FV= future value
# o PV= present value
# o r= annual interest rate (as a decimal)
# o t= time in years
# Take PV, r, and t as inputs from the user.

# %%
PV = eval(input("Enter present value : "))
r = float(input("Enter annual interest rate : "))
t = eval(input("Enter time in years : "))
FV = PV*(1+r)**t
print(f"Future value of investment = {FV}")
# Out:
# Enter present value :  23
# Enter annual interest rate :  4.5
# Enter time in years :  4.5
# Future value of investment = 49358.271069069415

# %% [raw]
# 19) Work Done by a Force:
# Write a Python program to calculate the work done by a force. Use the formula:
# where:
# W = work done
# f= force
# d = distance
# theta = angle between force and direction of movement (in degrees)
# Take f, d, and θ as inputs from the user

# %%
import math
F = eval(input("Enter force in N : "))
d = eval(input("Enter distance in m : "))
theta = eval(input("Enter theta in degrees : "))
W = F*d*math.cos(theta)
print(f"Workdone = {W}")
# Out:
# Enter force in N :  23
# Enter distance in m :  2
# Enter theta in degrees :  60
# Workdone = -43.81099709909719

# %% [raw]
#  20) Heat Transfer:
# Write a Python program to calculate the amount of heat transferred. Use the formula:
# where:
# Q= heat transfer
# m = mass
# c = specific heat capacity
# ΔT
# Take m, c, T as inputs from the user.

# %%
m = eval(input("Enter mass in kg : "))
c = eval(input("Enter specific heat capacity of material J/kg.K : "))
delta_T = eval(input("Enter change in temperature in K : "))
Q = m*c*delta_T
print(f"Heat transfer = {Q}")
# Out:
# Enter mass in kg :  12
# Enter specific heat capacity of material J/kg.K :  234
# Enter change in temperature in K :  456
# Heat transfer = 1280448
